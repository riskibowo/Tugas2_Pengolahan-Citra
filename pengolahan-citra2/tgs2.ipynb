# %%
# Import libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Membaca Gambar
img = cv2.imread("ps.png")

# %%
# menambahkan pixel 100 ke gambar 
numpyImg = img+100

# %%
# Menampilkan Gambar
plt.imshow(numpyImg[:,:,::-1])
plt.show()

# %%
# Menggunakan libari OpenCV
opencvImg = cv2.add(img,100)

# %%
# Menampilkan gambar pake opencv
plt.imshow(opencvImg[:,:,::-1])
plt.show()
img.shape
nparr = np.ones((924,1280,3),dtype=np.uint8) * 100
opencvImg = cv2.add(img,nparr)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 6
#       4 img.shape
#       5 nparr = np.ones((924,1280,3),dtype=np.uint8) * 100
# ----> 6 opencvImg = cv2.add(img,nparr)
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
# Menampilkan Gambar
plt.imshow(opencvImg[:,:,::-1])
plt.show()
npImg = img + nparr

# %%
# Menampilkan Gambar
plt.imshow(npImg[:,:,::-1])
plt.show()
